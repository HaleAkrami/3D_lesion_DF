# %%
# !pwd
# Out:
# /project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/T1_T2_v2/v3registered_non_iso/Brats21/t1/BraTS2021_00350_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 120  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/T1_T2_v2/v3registered_non_iso/Brats21/t2/BraTS2021_00350_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 120  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/T1_T2_v2/v3registered_non_iso/Brats21/seg/BraTS2021_00350_seg.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 120  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/T1_T2_v2/v3registered_non_iso/CamCan/t1/sub-CC221565_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/T1_T2_v2/v3registered_non_iso/CamCan/t2/sub-CC221565_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/CamCan_all_versions/camcan_all/sub-CC210088/T1mni.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (182, 218, 182)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/T1_T2_v2/v3registered_non_iso/HCP/t1/135932_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/T1_T2_v2/v3registered_non_iso/HCP/t2/135932_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %% [markdown]
# # Biobank

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/ajoshi/BrainAge_Preproc_FS7.1.1/1002735_20216_2_0_oriented_BF_adj/nu_T1_brain_6dof2Ref.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (182, 218, 182)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_T1/v4correctedN4_non_iso_cut/BioBank/t1/1002735_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (134, 176, 140)

# %% [markdown]
# # IXI

# %% [markdown]
# ## raw

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/IXI/t1/IXI002-Guys-0828-T1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (256, 256, 150)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/IXI/t2/IXI002-Guys-0828-T2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (256, 256, 130)

# %% [markdown]
# ## resample

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch_v2/v1resampled/IXI/t1/IXI002-Guys-0828_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (180, 240, 240)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch_v2/v1resampled/IXI/t2/IXI002-Guys-0828_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 163)

# %%
# import nibabel as nib
# import matplotlib.pyplot as plt

# # Load the NIfTI file
# filename = '/scratch1/akrami/Data_patch_v2/v3registered_non_iso_cut/IXI/t1/IXI002-Guys-0828_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
# #filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
# nifti_img = nib.load(filename)

# # Access the image data as a NumPy array
# data = nifti_img.get_fdata()
# print(data.shape)
# # Display a slice of the image
# slice_index = 50  # Adjust this value to visualize a different slice
# plt.imshow(data[:, :, slice_index], cmap='gray')
# plt.title(f'Slice {slice_index}')
# plt.axis('off')
# plt.show()

# %%
# import nibabel as nib
# import matplotlib.pyplot as plt

# # Load the NIfTI file
# filename = '/scratch1/akrami/Data_patch_v2/v3registered_non_iso_cut/IXI/t2/IXI002-Guys-0828_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
# #filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
# nifti_img = nib.load(filename)

# # Access the image data as a NumPy array
# data = nifti_img.get_fdata()
# print(data.shape)
# # Display a slice of the image
# slice_index = 50  # Adjust this value to visualize a different slice
# plt.imshow(data[:, :, slice_index], cmap='gray')
# plt.title(f'Slice {slice_index}')
# plt.axis('off')
# plt.show()

# %% [markdown]
# ## Brain extraction

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch_v2/v2skullstripped/IXI/t1/IXI002-Guys-0828_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 130  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (180, 240, 240)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch_v2/v2skullstripped/IXI/t2/IXI002-Guys-0828_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 130  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 163)

# %% [markdown]
# ## non_iso

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch/v3registered_non_iso/IXI/t2/IXI002-Guys-0828_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_T1/v3registered_non_iso/IXI/t1/IXI002-Guys-0828_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %% [markdown]
# ## Bias

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch/v4correctedN4_non_iso_cut/IXI/t2/IXI002-Guys-0828_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (138, 173, 137)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_T1/v4correctedN4_non_iso_cut/IXI/t1/IXI002-Guys-0828_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (137, 175, 139)

# %% [markdown]
# ## rigid T1-T2

# %%
# import nibabel as nib
# import matplotlib.pyplot as plt

# # Load the NIfTI file
# filename = '/scratch1/akrami/Data_patch/v3registered_non_iso/IXI/t1/IXI002-Guys-0828_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
# #filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
# nifti_img = nib.load(filename)

# # Access the image data as a NumPy array
# data = nifti_img.get_fdata()
# print(data.shape)
# # Display a slice of the image
# slice_index = 70  # Adjust this value to visualize a different slice
# plt.imshow(data[:, :, slice_index], cmap='gray')
# plt.title(f'Slice {slice_index}')
# plt.axis('off')
# plt.show()

# %% [markdown]
# # HCP

# %%
# numner of starting T1: 1113
# number of starting T2: 1113
# number of end T1: 1113
# number of end T2:1113

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/HCP/t1/130720_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()

# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/HCP/t2/130720_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()

# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch_v2/v3registered_non_iso/HCP/t2/130720_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_T1/v3registered_non_iso/HCP/t1/130720_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch_v2/v4correctedN4_non_iso_cut/HCP/t2/130720_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (135, 175, 141)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_T1/v4correctedN4_non_iso_cut/HCP/t1/130720_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (136, 176, 142)

# %% [markdown]
# # CamCan

# %%
# numner of starting T1:653
# number of starting T2: 653
# number of end T1:653
# number of end T2:653

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/CamCan/t1/sub-CC220198-T1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()

# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/CamCan/t2/sub-CC510415_T2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()

# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_T1/v3registered_non_iso/CamCan/t1/sub-CC220198_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch_v2/v3registered_non_iso/CamCan/t2/sub-CC220198_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch_v2/v1resampled/CamCan/t2/sub-CC110033_T2w_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()

# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_T1/v4correctedN4_non_iso_cut/CamCan/t1/sub-CC220198_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (136, 178, 143)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch_v2/v4correctedN4_non_iso_cut/CamCan/t2/sub-CC220198_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 70  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (135, 177, 140)

# %% [markdown]
# # MSLUB

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/MSLUB/t1/patient08_T1W.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 250  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (192, 512, 512)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/MSLUB/t2/patient08_T2W.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 250  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (192, 512, 512)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/MSLUB/seg/patient08_consensus_gt.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 250  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (192, 512, 512)

# %% [markdown]
# ## resampled

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch/v1resampled/MSLUB/t2/patient08_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 130  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (154, 240, 240)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch/v2skullstripped/MSLUB/t2/patient08_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 130  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (154, 240, 240)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch/v3registered_non_iso/MSLUB/t2/patient08_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_T1/v3registered_non_iso/MSLUB/t1/patient08_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch/v4correctedN4_non_iso_cut/MSLUB/t2/patient08_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (138, 171, 128)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_T1/v4correctedN4_non_iso_cut/MSLUB/t1/patient08_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (137, 172, 121)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Data_T1/v5registered_non_iso/MSLUB/t2/patient08_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.conda/envs/working_monai/lib/python3.9/site-packages/nibabel/loadsave.py:87, in load(filename, **kwargs)
#      86 try:
# ---> 87     stat_result = os.stat(filename)
#      88 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/scratch1/akrami/Data_T1/v5registered_non_iso/MSLUB/t2/patient08_t2.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 7
#       5 filename = '/scratch1/akrami/Data_T1/v5registered_non_iso/MSLUB/t2/patient08_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#       6 #filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz'
# ----> 7 nifti_img = nib.load(filename)
# ...

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch/v3registered_non_iso/MSLUB/seg/patient01_seg.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (240, 240, 155)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch/v4correctedN4_non_iso_cut/MSLUB/seg/patient01_seg.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (135, 175, 129)

# %% [markdown]
# # Brats

# %% [markdown]
# ## raw

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/Brats21/t2/BraTS2021_00350_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()

# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/Brats21/t1/BraTS2021_00350_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()

# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()

# %% [markdown]
# ## bias corrected

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_patch/v4correctedN4_non_iso_cut/Brats21/t2/BraTS2021_00350_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (137, 177, 136)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_T1/v4correctedN4_non_iso_cut/Brats21/t1/BraTS2021_00350_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 75  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (138, 179, 137)

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/CamCan/t1/sub-CC221565_t1.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()

# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '/scratch1/akrami/Latest_Data/Data_pre/CamCan/t2/sub-CC221565_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()

# Display a slice of the image
slice_index = 50  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.conda/envs/working_monai/lib/python3.9/site-packages/nibabel/loadsave.py:87, in load(filename, **kwargs)
#      86 try:
# ---> 87     stat_result = os.stat(filename)
#      88 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/scratch1/akrami/Latest_Data/Data_pre/CamCan/t2/sub-CC221565_t2.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 7
#       5 filename = '/scratch1/akrami/Latest_Data/Data_pre/CamCan/t2/sub-CC221565_t2.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#       6 #filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz'
# ----> 7 nifti_img = nib.load(filename)
# ...

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the NIfTI file
filename = '//scratch1/akrami/unsorted_data/NFBS_Dataset/A00028185/sub-A00028185_ses-NFB3_T1w_brain.nii.gz' #CamCan/t1/sub-CC110033.nii.gz'
#filename = '/project/ajoshi_27/akrami/patched-Diffusion-Models-UAD/preprocessing/notebooks/data/CamCan/t1/sub-CC110033.nii.gz' 
nifti_img = nib.load(filename)

# Access the image data as a NumPy array
data = nifti_img.get_fdata()
print(data.shape)
# Display a slice of the image
slice_index = 100  # Adjust this value to visualize a different slice
plt.imshow(data[:, :, slice_index], cmap='gray')
plt.title(f'Slice {slice_index}')
plt.axis('off')
plt.show()
# Out:
# (256, 256, 192)
